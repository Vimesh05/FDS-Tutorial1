# %%
from numpy import random
x=random.choice([2,4,6,8],p=[0.1,0.3,0.6,0.0],size=(100))
print(x)
# Out:
# [6 2 6 6 6 4 6 6 6 6 4 4 6 6 6 6 6 2 6 6 2 4 4 6 6 6 6 6 4 4 4 6 6 2 4 4 4
#  6 4 6 6 6 2 4 6 4 6 4 6 6 6 4 4 6 6 4 4 4 4 6 6 6 6 4 6 6 6 6 6 2 4 6 6 4
#  4 6 4 6 6 4 6 6 6 6 4 4 6 4 4 6 6 6 4 4 6 6 6 4 6 6]

# %%
from numpy import random
x=random.choice([2,4,6,8],p=[0.1,0.3,0.6,0.0],size=(3,5))
print(x)
# Out:
# [[6 6 6 6 6]
#  [6 2 6 6 6]
#  [6 4 4 4 6]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(size=1000),hist=False)
plt.show()
# Out:
# C:\Users\tamil\AppData\Local\Temp\ipykernel_13284\799546936.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000),hist=False)

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(size=1000),hist=True)
plt.show()
# Out:
# C:\Users\tamil\AppData\Local\Temp\ipykernel_13284\1169273569.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000),hist=True)

# %%
from numpy import random
x=random.binomial(n=10,p=0.5,size=10)
print(x)
# Out:
# [2 6 3 3 4 6 5 3 5 6]

# %%
from numpy import random
x=random.binomial(n=164,p=0.5,size=302)
print(x)
# Out:
# [77 81 84 78 94 70 90 80 79 78 76 86 94 73 80 85 74 90 77 89 76 90 82 86
#  86 72 80 87 74 73 87 85 78 83 88 83 80 80 75 78 84 76 78 79 91 73 82 91
#  88 67 67 96 81 88 66 78 80 85 78 91 82 77 81 79 89 72 89 66 67 85 94 81
#  85 74 87 80 75 77 82 81 87 73 83 72 82 83 91 85 89 76 87 80 92 83 86 89
#  94 84 82 77 76 81 71 96 84 76 84 90 87 81 72 81 73 93 86 91 76 82 84 79
#  84 86 93 81 87 81 76 71 83 84 80 84 80 82 91 81 74 88 92 89 77 78 83 82
#  81 72 78 78 73 78 94 83 87 89 73 83 82 81 80 80 73 90 79 81 73 84 93 76
#  80 79 71 85 91 80 75 85 89 75 75 93 75 73 91 86 75 84 72 81 81 86 78 81
#  78 95 83 86 80 94 69 71 78 85 74 84 89 80 77 84 79 89 80 87 89 82 72 74
#  94 82 73 90 85 89 88 83 84 84 80 73 76 89 83 86 87 95 74 73 85 80 74 85
#  82 82 96 78 86 77 79 84 85 87 86 83 75 89 84 68 77 84 91 85 87 84 75 88
#  87 86 95 77 77 86 89 82 86 81 84 80 95 71 74 77 75 78 79 96 77 87 69 81
#  95 79 86 86 84 78 76 76 78 77 72 87 88 81]
